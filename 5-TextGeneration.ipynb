# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                                        transcript  \
# BattleCreekDec19_2019.txt       Thank you. Thank you. Thank you to Vice Presid...
# BemidjiSep18_2020.txt           There's a lot of people. That's great. Thank y...
# CharlestonFeb28_2020.txt        Thank you. Thank you. Thank you. All I can say...
# CharlotteMar2_2020.txt          I want to thank you very much. North Carolina,...
# CincinnatiAug1_2019.txt         Thank you all. Thank you very much. Thank you ...
# ColoradorSpringsFeb20_2020.txt  Hello Colorado. We love Colorado, most beautif...
# DallasOct17_2019.txt            Thank you. Thank you very much. Hello Dallas. ...
# DesMoinesJan30_2020.txt         I worked so hard for this state. I worked so h...
# FayettevilleSep19_2020.txt      What a crowd, what a crowd. Get those people o...
# FayettevilleSep9_2019.txt        Thank you everybody. Thank you and Vice Presi...
# FreelandSep10_2020.txt          We brought you a lot of car plants, Michigan. ...
# GreenvilleJul17_2019.txt        Thank you very much. Thank you. Thank you. Tha...
# HendersonSep13_2020.txt         Thank you, thank you. Wow. Wow, and I'm thrill...
# HersheyDec10_2019.txt            Well, thank you to Vice President Pence. Than...
# LasVegasFeb21_2020.txt          Well, thank you very much. And hello Las Vegas...
# LatrobeSep3_2020.txt            So thank you Pennsylvania, very much. I'm thri...
# LexingtonNov4_2019.txt          Thank you very much and thank you to the origi...
# MilwaukeeJan14_2020.txt         Well thank you very much. And I'm thrilled to ...
# MindenSep12_2020.txt            Well, I thank you very much. So I want to star...
# MinneapolisOct10_2019.txt       Thank you very much. Thank you, Minnesota. Thi...
# MosineeSep17_2020.txt           Thank you, thank you very much. Thank you very...
# NewHampshireAug15_2019.txt       Thank you very much everybody. Thank you. Wow...
# NewHampshireAug28_2020.txt      Hello, everybody. Hello, everybody. Wow. Hello...
# NewHampshireFeb10_2020.txt      Hello, Manchester, and I am thrilled to be in ...
# NewMexicoSep16_2019.txt          Wow, thank you. Thank you, New Mexico. Thank ...
# OhioSep21_2020.txt              Wow, that's a big crowd. This is a big crowd. ...
# PhoenixFeb19_2020.txt            Thank you very much, Phoenix. We love to be b...
# PittsburghSep22_2020.txt        Doesn't have the power. Doesn't have the stayi...
# TexasSep23_2019.txt             Hello, Houston. I am so thrilled to be here in...
# ToledoJan9_2020.txt             Well, thank you very much. Vice President Mike...
# TulsaJun20_2020.txt             Thank you, thank you. So we begin, Oklahoma, w...
# TupeloNov1_2019.txt             ell, thank you very much. And hello, Tupelo. T...
# WildwoodJan28_2020.txt          Thank you. Thank you. I love New Jersey and I'...
# Winston-SalemSep8_2020.txt      Well, thank you very much. Thank you. Thank yo...
# YumaAug18_2020.txt              Oh, thank you very much, everybody. Thank you....
#
#                                                  full_name
# BattleCreekDec19_2019.txt            BattleCreekDec19_2019
# BemidjiSep18_2020.txt                    BemidjiSep18_2020
# CharlestonFeb28_2020.txt              CharlestonFeb28_2020
# CharlotteMar2_2020.txt                  CharlotteMar2_2020
# CincinnatiAug1_2019.txt                CincinnatiAug1_2019
# ColoradorSpringsFeb20_2020.txt  ColoradorSpringsFeb20_2020
# DallasOct17_2019.txt                      DallasOct17_2019
# DesMoinesJan30_2020.txt            DesMoinesJan30_2020.txt
# FayettevilleSep19_2020.txt          FayettevilleSep19_2020
# FayettevilleSep9_2019.txt            FayettevilleSep9_2019
# FreelandSep10_2020.txt                  FreelandSep10_2020
# GreenvilleJul17_2019.txt              GreenvilleJul17_2019
# HendersonSep13_2020.txt                HendersonSep13_2020
# HersheyDec10_2019.txt                    HersheyDec10_2019
# LasVegasFeb21_2020.txt                  LasVegasFeb21_2020
# LatrobeSep3_2020.txt                      LatrobeSep3_2020
# LexingtonNov4_2019.txt                  LexingtonNov4_2019
# MilwaukeeJan14_2020.txt                MilwaukeeJan14_2020
# MindenSep12_2020.txt                      MindenSep12_2020
# MinneapolisOct10_2019.txt            MinneapolisOct10_2019
# MosineeSep17_2020.txt                    MosineeSep17_2020
# NewHampshireAug15_2019.txt          NewHampshireAug15_2019
# NewHampshireAug28_2020.txt          NewHampshireAug28_2020
# NewHampshireFeb10_2020.txt          NewHampshireFeb10_2020
# NewMexicoSep16_2019.txt                NewMexicoSep16_2019
# OhioSep21_2020.txt                          OhioSep21_2020
# PhoenixFeb19_2020.txt                    PhoenixFeb19_2020
# PittsburghSep22_2020.txt              PittsburghSep22_2020
# TexasSep23_2019.txt                        TexasSep23_2019
# ToledoJan9_2020.txt                        ToledoJan9_2020
# TulsaJun20_2020.txt                        TulsaJun20_2020
# TupeloNov1_2019.txt                        TupeloNov1_2019
# WildwoodJan28_2020.txt                  WildwoodJan28_2020
# Winston-SalemSep8_2020.txt          Winston-SalemSep8_2020
# YumaAug18_2020.txt                          YumaAug18_2020

# %%
# Extract only one speech
test_text = data.transcript.loc['TexasSep23_2019.txt']
test_text[:200]
# Out:
# "Hello, Houston. I am so thrilled to be here in the great state of Texas with one of America's greatest, most devoted and most loyal friends, Prime Minister Modi of India. Thank you. Thank you. And Pri"

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for the Texas Speech
test_dict = markov_chain(test_text)
test_dict
# Out:
# {'Hello,': ['Houston.'],
#  'Houston.': ['I'],
#  'I': ['am',
#   'understand',
#   'know',
#   'want',
#   'just',
#   'was',
#   'know',
#   'have',
#   'want',
#   'want',
#   'promised',
#   'can',
#   'can',
#   'look',
#   'want',
#   'invited,',
#   'may',
#   'may',
#   'want',
#   'will',
#   'want',
#   'want',
#   'want',
#   'would'],
#  'am': ['so'],
#  'so': ['thrilled'],
#  'thrilled': ['to', 'to'],
#  'to': ['be',
#   'be',
#   'be',
#   'the',
#   'take',
#   'address',
#   'Houston',
#   'celebrate',
#   'express',
#   'the',
#   'be',
#   'have',
#   'know',
#   'recognize',
#   'India',
#   'report',
#   'democracy.',
#   'our',
#   'justice,',
#   'the',
#   'our',
#   'be',
#   "America's",
#   'this',
#   'strengthen',
#   'save',
#   'thousands',
#   'working',
#   'make',
#   'hire,',
#   '$500',
#   'revitalize',
#   'thank',
#   'say',
#   'expand',
#   'India,',
#   'ensuring',
#   'the',
#   'another',
#   'watch',
#   'expanding',
#   'hear',
#   'purchase',
#   '5',
#   'billions',
#   'India',
#   'India',
#   'soar',
#   'India',
#   'concluding',
#   'enhance',
#   'safeguard',
#   'protecting',
#   'keep',
#   'improve',
#   'ensure',
#   'the',
#   'India.',
#   'finally',
#   'thank',
#   'millions',
#   '…',
#   'fund',
#   'those',
#   'do',
#   'do',
#   'take',
#   'illegal',
#   'the',
#   'take',
#   'take',
#   'pour',
#   'build',
#   'great',
#   'reach',
#   'say',
#   'always',
#   'play',
#   'deepen',
#   'thank',
#   'especially',
#   'invite',
#   'give',
#   'be'],
#  'be': ['here',
#   'here',
#   'joined',
#   'there',
#   'American',
#   'done.',
#   'broken',
#   'a',
#   'setting',
#   'for',
#   'close.',
#   'with'],
#  'here': ['in',
#   'with',
#   'joins',
#   'today',
#   'today',
#   'in',
#   'in',
#   'in',
#   'from',
#   'today'],
#  'in': ['the',
#   'the',
#   'the',
#   'wishing',
#   'the',
#   'our',
#   'America',
#   'Texas',
#   'Texas',
#   'the',
#   'the',
#   'over',
#   'the',
#   'many,',
#   'rising',
#   'history,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'our',
#   'the',
#   'India.',
#   'Texas.',
#   'the',
#   'the',
#   'Mumbai',
#   'India.',
#   'the',
#   'America,',
#   'the',
#   'the',
#   'America,',
#   'defense',
#   'every',
#   'a',
#   'Washington',
#   'a',
#   'a',
#   'concluding,',
#   'building',
#   'space,',
#   'front'],
#  'the': ['great',
#   'Indian',
#   'largest',
#   'history',
#   'polls',
#   'recent',
#   'way.',
#   'Coast',
#   'Texas',
#   'same',
#   'nearly',
#   'leaders',
#   'House',
#   'audience,',
#   'White',
#   'relationship',
#   'United',
#   'rule',
#   'same',
#   'People."',
#   'citizens',
#   'world',
#   'help',
#   'next',
#   'middle',
#   'United',
#   'United',
#   'lowest',
#   'history',
#   'United',
#   'lowest',
#   'history',
#   'last',
#   'unemployment',
#   'fastest',
#   'past',
#   'average',
#   'other',
#   'first',
#   'biggest',
#   'biggest',
#   'history',
#   'average',
#   'history',
#   'presidency,',
#   'Indian',
#   'world',
#   'United',
#   'great',
#   'Lone',
#   'world',
#   'United',
#   'best',
#   'best',
#   'world.',
#   'United',
#   'same',
#   'same',
#   "world's",
#   'Indian',
#   'finest',
#   'world,',
#   'USA."',
#   'first',
#   'first',
#   'United',
#   'number',
#   'great',
#   'pump.',
#   'Indian',
#   'United',
#   'coming',
#   'last',
#   'United',
#   'past',
#   'greatest',
#   'world',
#   'works.',
#   'United',
#   'United',
#   'first',
#   'brave',
#   'threat',
#   'United',
#   'aspects',
#   'United',
#   'president',
#   'highest',
#   'American',
#   'best',
#   'American',
#   'American',
#   'story',
#   'nation',
#   'awesome',
#   'ties',
#   'faith',
#   'world.',
#   'sights',
#   'leader'],
#  'great': ['state',
#   'governor',
#   'senators.',
#   'friend',
#   'faith',
#   'senators',
#   'American',
#   'state',
#   'state',
#   'school,',
#   'man',
#   'leader,',
#   'honor'],
#  'state': ['of', 'attorney', 'of', 'of'],
#  'of': ['Texas',
#   "America's",
#   'India.',
#   'the',
#   'our',
#   'our',
#   'people.',
#   'Houston',
#   'the',
#   'India.',
#   'Kentucky,',
#   'very',
#   'senators.',
#   'Congress',
#   'the',
#   'that.',
#   'law,',
#   'liberty.',
#   'India.',
#   'Prime',
#   'poverty',
#   'our',
#   'this.',
#   'our',
#   'our',
#   'the',
#   'prime',
#   'our',
#   'job',
#   'our',
#   'our',
#   'thousands',
#   'Americans',
#   'industries,',
#   'Ohio.',
#   'almost',
#   'the',
#   'people',
#   'both',
#   'it',
#   'Texas.',
#   'LNG',
#   'dollars',
#   'LNG',
#   'it.',
#   'them',
#   'our',
#   'the',
#   'liberty',
#   'radical',
#   'applications',
#   'the',
#   'border',
#   'Mexico,',
#   'time.',
#   'wonderful',
#   'all.',
#   'our',
#   'our',
#   'illegal',
#   'pioneers',
#   'American',
#   'India,',
#   'democracy',
#   'free',
#   'dignity',
#   'our',
#   'lives.',
#   'people',
#   'poverty.',
#   'humanity.',
#   'India,',
#   'this',
#   'unbelievable',
#   'his'],
#  'Texas': ['with', 'flooding.', 'and', 'manufacturing', 'is'],
#  'with': ['one',
#   'him',
#   'you',
#   'your',
#   'the',
#   'great',
#   'the',
#   'the',
#   'tax',
#   'you',
#   'a',
#   'much',
#   'India',
#   'access',
#   'the',
#   'you.'],
#  'one': ['of', 'record', 'third', 'of', 'producer', 'by', 'of'],
#  "America's": ['greatest,', 'workers,'],
#  'greatest,': ['most'],
#  'most': ['devoted', 'loyal', 'new'],
#  'devoted': ['and'],
#  'and': ['most',
#   'for',
#   'hardworking',
#   'voted',
#   'his',
#   'senators',
#   'Ted',
#   'rebuilt',
#   'I',
#   'I',
#   'India,',
#   'bright',
#   'you',
#   'we',
#   'I',
#   'every',
#   'Minister',
#   'Senate.',
#   'again,',
#   'great',
#   'I',
#   'India',
#   'our',
#   'a',
#   'strengthened',
#   'fight',
#   'thriving',
#   'that',
#   'the',
#   'cutting',
#   'all',
#   'congressmen',
#   'women',
#   'pro',
#   'very',
#   'unemployment',
#   'very',
#   'Hispanic',
#   'one',
#   'inequality',
#   'over',
#   'all',
#   'women.',
#   'training',
#   'the',
#   'never',
#   'build',
#   "they're",
#   'pursue',
#   'the',
#   'India',
#   'Aisin,',
#   'natural',
#   'number',
#   'lower',
#   'liquefied',
#   'security',
#   'India',
#   'equipment',
#   'India',
#   "we're",
#   'India',
#   'Indian',
#   'we',
#   'the',
#   'vetting',
#   'we',
#   'we',
#   "we'll",
#   'stop',
#   'obey',
#   'US-born,',
#   'have',
#   'patriots,',
#   'free',
#   'dedicated',
#   'teach',
#   'everyone',
#   'greater',
#   'Indian',
#   'we',
#   'unlimited',
#   'we',
#   'for',
#   'save',
#   'lift',
#   'millions',
#   'control',
#   'India',
#   'our',
#   'it',
#   'a',
#   'God'],
#  'loyal': ['friends,'],
#  'friends,': ['Prime'],
#  'Prime': ['Minister',
#   'Minister',
#   'Minister',
#   'Minister.',
#   'Minister',
#   'Minister',
#   'Minister',
#   'Minister',
#   'Minister?',
#   'Minister',
#   'Minister'],
#  'Minister': ['Modi',
#   'Modi',
#   'Modi',
#   'Modi',
#   'Jaishankar',
#   "Modi's",
#   "Modi's",
#   'Modi,',
#   'Modi,',
#   'Modi,'],
#  'Modi': ['of', 'is', 'and', 'and'],
#  'India.': ['Thank', 'Thank', 'In', 'On', 'Am', 'To', 'We'],
#  'Thank': ['you.',
#   'you.',
#   'you.',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you.',
#   'you',
#   'you,',
#   'you.',
#   'you,',
#   'you',
#   'you.',
#   'you.',
#   'you.',
#   'you.',
#   'you.',
#   'you',
#   'you.',
#   'you.'],
#  'you.': ['Thank',
#   'And',
#   'Just',
#   'We',
#   'We',
#   "We're",
#   'Thank',
#   'We',
#   'The',
#   'These',
#   'Both',
#   'God',
#   'Thank',
#   'Now',
#   'Thank',
#   'Thank'],
#  'And': ['Prime', 'for', "that's", 'we', 'we', 'I', 'very', 'we'],
#  'is': ['doing',
#   'my',
#   'standing',
#   'fighting',
#   'stronger',
#   'witnessing',
#   'an',
#   'breaking',
#   'currently',
#   'falling',
#   'helping',
#   'changing',
#   'doing',
#   'more',
#   'the',
#   'vital',
#   'vital',
#   'deeply',
#   'to',
#   'indeed'],
#  'doing': ['a', 'today.', 'the', 'it'],
#  'a': ['truly',
#   'few',
#   'lot',
#   'very',
#   'moment',
#   'problem.',
#   'couple',
#   'lot',
#   'lot',
#   'very,',
#   'true',
#   'better',
#   'fierce',
#   'strong',
#   'single',
#   'historic',
#   'record',
#   'better',
#   'range',
#   'shuttered',
#   'combined',
#   'beautiful',
#   'lot',
#   'dramatic',
#   'good',
#   'far-reaching',
#   'daily',
#   'short',
#   'nation',
#   'safe',
#   'job',
#   'nation',
#   'trade,',
#   'crucial',
#   'great',
#   'great',
#   'great'],
#  'truly': ['exceptional', 'proud'],
#  'exceptional': ['job'],
#  'job': ['for', 'killing', 'killing', 'you'],
#  'for': ['India',
#   'all',
#   'Prime',
#   'you',
#   'being',
#   'being',
#   'this',
#   'president,',
#   'the',
#   'the',
#   'nearly',
#   'American',
#   'India.',
#   'entry.',
#   'the',
#   'our',
#   'our',
#   'the',
#   'being'],
#  'India': ['and',
#   'Kenneth',
#   'would',
#   'is',
#   'alike,',
#   'has',
#   'and',
#   'has',
#   'will',
#   'in',
#   'have',
#   'forging',
#   'have',
#   'knows',
#   'to',
#   'will',
#   'and',
#   'will'],
#  'all': ['of',
#   'across',
#   'for',
#   'for',
#   'over',
#   'of',
#   'of',
#   'reached',
#   'of',
#   'of',
#   'very'],
#  'Indian': ['people.',
#   'American',
#   'Americans',
#   'households',
#   'Americans',
#   'American',
#   'Americans',
#   'companies',
#   'people',
#   'company',
#   'military',
#   'future.'],
#  'people.': ['It', 'Earlier', "There's", 'Together,'],
#  'It': ['is'],
#  'my': ['immense',
#   'profound',
#   'administration',
#   'campaign',
#   'election,',
#   'administration',
#   'friend.'],
#  'immense': ['privilege'],
#  'privilege': ['to'],
#  'him': ['today'],
#  'today': ['at', 'for', 'and', 'are', 'has'],
#  'at': ['this', 'Ellington', 'the', 'the', 'the', 'record'],
#  'this': ['profoundly',
#   'week,',
#   'remarkable',
#   'day,',
#   'extent.',
#   'stage',
#   'incredible'],
#  'profoundly': ['historic'],
#  'historic': ['event.', 'number.'],
#  'event.': ["We're"],
#  "We're": ['especially',
#   'ready.',
#   'working',
#   'working',
#   'also',
#   'looking',
#   'doing'],
#  'especially': ['grateful', 'thank'],
#  'grateful': ['to'],
#  'joined': ['by', 'by'],
#  'by': ['over',
#   'the',
#   'your',
#   'NASA',
#   'the',
#   'commitment',
#   'our',
#   'nearly',
#   'far,',
#   '400%'],
#  'over': ['50,000', 'the', '6', '750,000', '51', '$3,000', '900', 'the'],
#  '50,000': ['incredible'],
#  'incredible': ['members', 'number.', "what's", 'advancements', 'group'],
#  'members': ['of', 'of', 'who'],
#  'our': ["nation's",
#   'world,',
#   'shared',
#   'country.',
#   'culture,',
#   'values,',
#   'communities',
#   'two',
#   'common',
#   'shared',
#   'national',
#   'love',
#   'massive',
#   'great',
#   'economy',
#   'country,',
#   'country.',
#   'pledge',
#   'great',
#   'country.',
#   'country,',
#   'country',
#   'future.',
#   'fellow',
#   'nations',
#   'country',
#   'commercial',
#   'nation',
#   'defense',
#   'nations.',
#   'freedom.',
#   'communities',
#   'borders.',
#   'security',
#   'country',
#   'vetting',
#   'vetting',
#   'southern',
#   'southern',
#   'rules,',
#   'laws.',
#   'country',
#   'first',
#   'citizens',
#   'Indian-American',
#   'country.',
#   'cherished',
#   'nations.',
#   'citizens,',
#   'people,',
#   'children,',
#   'values,',
#   'liberty,',
#   'destiny.',
#   'nations',
#   'people',
#   'dreamers',
#   'future'],
#  "nation's": ['thriving,'],
#  'thriving,': ['prospering,'],
#  'prospering,': ['flourishing,'],
#  'flourishing,': ['and'],
#  'hardworking': ['Indian'],
#  'American': ['community.',
#   'nation',
#   'and',
#   'workers',
#   'companies.',
#   'household',
#   'community',
#   'steel.',
#   'exports',
#   'product,',
#   'and',
#   'people,',
#   'dream.',
#   'dream.',
#   'greatness,',
#   'and'],
#  'community.': ['Thank'],
#  'Just': ['a', 'in'],
#  'few': ['months'],
#  'months': ['ago', 'alone,'],
#  'ago': ['in'],
#  'largest': ['democratic'],
#  'democratic': ['election'],
#  'election': ['in'],
#  'history': ['of', 'of', 'of', 'of', 'of'],
#  'world,': ['600', 'product'],
#  '600': ['million'],
#  'million': ['Indians',
#   'amazing',
#   'people',
#   'Indian',
#   'new',
#   'employment',
#   'to',
#   'tons'],
#  'Indians': ['went'],
#  'went': ['to'],
#  'polls': ['and'],
#  'voted': ['overwhelmingly'],
#  'overwhelmingly': ['for'],
#  'his': ['party.', 'wisdom.'],
#  'party.': ['Congratulations,'],
#  'Congratulations,': ['Mr.'],
#  'Mr.': ['Prime', 'Brady,', 'Prime'],
#  'Minister.': ["That's"],
#  "That's": ['a', 'incredible.'],
#  'lot': ['of', 'of', 'of', 'of'],
#  'Earlier': ['this'],
#  'week,': ['I'],
#  'understand': ['you', 'that', 'that.'],
#  'you': ['marked',
#   'a',
#   'every',
#   'very',
#   'have',
#   'will',
#   'uphold',
#   'uplift',
#   'are',
#   'as',
#   'and',
#   'to',
#   'each',
#   'very',
#   'both.',
#   'very',
#   'all',
#   'all',
#   'have',
#   'to',
#   'love,',
#   'all.',
#   'all'],
#  'marked': ['another'],
#  'another': ['important', 'world'],
#  'important': ['milestone.', 'than'],
#  'milestone.': ['I'],
#  'know': ['everyone', 'you', 'my', 'we'],
#  'everyone': ['here', 'here'],
#  'joins': ['me'],
#  'me': ['in'],
#  'wishing': ['you'],
#  'very': ['happy',
#   'much.',
#   'much.',
#   'much.',
#   'great',
#   'nice',
#   'much.',
#   'importantly,',
#   'soon',
#   'soon,',
#   'soon.',
#   'best.',
#   'much.'],
#  'happy': ['birthday.', 'to'],
#  'birthday.': ['Happy', 'I'],
#  'Happy': ['birthday.'],
#  'want': ['to',
#   'you',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to'],
#  'take': ['a', 'away', 'care', 'care', 'care'],
#  'moment': ['to'],
#  'address': ['every'],
#  'every': ['resident',
#   'single',
#   'single',
#   'time',
#   'day.',
#   'year',
#   'one',
#   'family,'],
#  'resident': ['of'],
#  'Houston': ['effected', 'to'],
#  'effected': ['by'],
#  'recent': ['horrible'],
#  'horrible': ['flooding.'],
#  'flooding.': ['The', "We're"],
#  'The': ['entire', 'prime', 'ties', 'economic', 'United'],
#  'entire': ['American'],
#  'nation': ['is', 'safe,', 'where', 'of', 'of'],
#  'standing': ['by'],
#  'your': ['side.', 'great', 'state', 'dreams.', 'healthcare', 'healthcare'],
#  'side.': ["We're"],
#  'ready.': ['We'],
#  'We': ['love',
#   'support',
#   'will',
#   'thank',
#   'have',
#   'have',
#   'are',
#   'are',
#   'have',
#   'passed',
#   'slashed',
#   'are',
#   'make',
#   'stand',
#   'are',
#   'understand',
#   'are',
#   "don't",
#   "don't",
#   'must',
#   'are',
#   'are',
#   'want',
#   'love',
#   'will',
#   'will',
#   'will',
#   'will',
#   'will'],
#  'love': ['you.', 'you', 'of', 'the'],
#  'support': ['you.'],
#  'will': ['be',
#   'not',
#   'come',
#   'rise',
#   'be',
#   'create',
#   'have',
#   'gather',
#   'demonstrate',
#   'never',
#   'continue',
#   'honor',
#   'achieve',
#   'discover',
#   'advance',
#   'pioneer',
#   'uphold',
#   'make'],
#  'there': ['with', 'has', 'are'],
#  'single': ['step', 'time,', 'decade,'],
#  'step': ['of'],
#  'way.': ['I'],
#  'just': ['left', 'reached', 'beginning.'],
#  'left': ['the'],
#  'Coast': ['Guard'],
#  'Guard': ['hanger'],
#  'hanger': ['at'],
#  'Ellington': ['Field'],
#  'Field': ['Joint'],
#  'Joint': ['Reserve'],
#  'Reserve': ['Base'],
#  'Base': ['where'],
#  'where': ['I', 'every'],
#  'was': ['briefed'],
#  'briefed': ['on'],
#  'on': ['the', 'planet', 'a', 'our'],
#  'working': ['with',
#   'hard',
#   'age',
#   'with',
#   'to',
#   'closely',
#   'hard',
#   'together,'],
#  'governor': ['Greg'],
#  'Greg': ['Abbott,'],
#  'Abbott,': ['Lieutenant'],
#  'Lieutenant': ['Governor'],
#  'Governor': ['Dan', 'Matt'],
#  'Dan': ['Patrick,', 'Brouillette,'],
#  'Patrick,': ['Attorney'],
#  'Attorney': ['General'],
#  'General': ['Ken'],
#  'Ken': ['Paxton', 'Paxton,'],
#  'Paxton': ['and'],
#  'senators': ['John', 'Cornyn,', 'and'],
#  'John': ['Cornyn'],
#  'Cornyn': ['and'],
#  'Ted': ['Cruz.'],
#  'Cruz.': ['Thank', 'In'],
#  'much.': ["We're", 'Thank', 'Thank', 'Thank', "It's"],
#  'hard': ['together.', 'to'],
#  'together.': ['My'],
#  'My': ['administration', 'administration'],
#  'administration': ['will', 'is', 'has', 'believes'],
#  'not': ['rest', 'only', 'even'],
#  'rest': ['until'],
#  'until': ['you'],
#  'have': ['fully',
#   'shown',
#   'come',
#   'you',
#   'a',
#   'a',
#   'a',
#   'never',
#   'created',
#   'created',
#   'all',
#   'secured',
#   'regulations',
#   'the',
#   'never',
#   'access',
#   'access',
#   'plenty',
#   'grown',
#   'also',
#   'the',
#   'honed'],
#  'fully': ['recovered,'],
#  'recovered,': ['restored,'],
#  'restored,': ['and'],
#  'rebuilt': ['and'],
#  'come': ['back', 'to', 'to'],
#  'back': ['with'],
#  'same': ['tremendous', 'three', 'thing', 'time,'],
#  'tremendous': ['spirit', 'exports'],
#  'spirit': ['that'],
#  'that': ['we',
#   'unites',
#   'President',
#   'the',
#   'in',
#   'is',
#   'are',
#   'includes',
#   "couldn't",
#   'will',
#   "we've",
#   'is',
#   'provide',
#   'it',
#   'well.',
#   'to',
#   'those',
#   'want',
#   'America',
#   'exciting'],
#  'we': ['have',
#   'are',
#   'love',
#   'were',
#   'honor,',
#   'proudly',
#   'are',
#   'have',
#   'think',
#   'have',
#   'welcome',
#   'have',
#   'want',
#   'are',
#   'were',
#   'have',
#   'honor',
#   'are',
#   'must',
#   'are',
#   'are',
#   "don't",
#   'take',
#   'are',
#   'are',
#   'will',
#   'will'],
#  'shown': ['every'],
#  'time,': ['every', 'we'],
#  'time': ["there's", 'in', "that's", 'to', 'ever,'],
#  "there's": ['been'],
#  'been': ['a', 'cut', 'a', 'incredible', 'a', 'a'],
#  'problem.': ["It's"],
#  "It's": ['called', 'called', 'been', 'been'],
#  'called': ['"Houston', 'Tiger'],
#  '"Houston': ['strong."'],
#  'strong."': ['Prime'],
#  'celebrate': ['everything'],
#  'everything': ['that'],
#  'unites': ['America'],
#  'America': ['and', 'AMD', 'has'],
#  'India,': ['our', 'one', 'and', 'Prime', 'and'],
#  'shared': ['dreams', 'commitment'],
#  'dreams': ['and'],
#  'bright': ['futures.'],
#  'futures.': ["I've"],
#  "I've": ['also'],
#  'also': ['come', 'proudly', 'reached', 'understand'],
#  'express': ['my'],
#  'profound': ['gratitude'],
#  'gratitude': ['to'],
#  'nearly': ['4', '300', '33', '14'],
#  '4': ['million'],
#  'amazing': ['Indian'],
#  'Americans': ['all', 'have', 'dropped', 'are', 'across'],
#  'across': ['our', 'a'],
#  'country.': ['You', 'Over', 'We', 'We'],
#  'You': ['enrich'],
#  'enrich': ['our'],
#  'culture,': ['you'],
#  'uphold': ['our', 'our'],
#  'values,': ['you', 'defend'],
#  'uplift': ['our'],
#  'communities': ['and', 'safe,'],
#  'are': ['truly',
#   'proud',
#   'many',
#   'grounded',
#   'free',
#   'governed',
#   'prospering',
#   'slashing',
#   'here',
#   'rising,',
#   'soaring,',
#   'minorities',
#   'pioneering',
#   'just',
#   'investing',
#   'today.',
#   'working',
#   'committed',
#   'a',
#   'committed',
#   'working',
#   'denied',
#   'enhancing',
#   'enhancing',
#   'further',
#   'those',
#   'going',
#   'going',
#   'strengthening',
#   'proving'],
#  'proud': ['to', 'to'],
#  'as': ['Americans.', 'president'],
#  'Americans.': ['We'],
#  'thank': ['you,', 'you.', 'everybody', 'the', 'everybody', 'a'],
#  'you,': ['we', 'Kevin.', 'Kevin,', 'you'],
#  'fighting': ['for'],
#  'each': ['and'],
#  'day.': ['I'],
#  'recognize': ['US'],
#  'US': ['Ambassador', 'defense'],
#  'Ambassador': ['to'],
#  'Kenneth': ['Juster'],
#  'Juster': ['and'],
#  'Jaishankar': ['of'],
#  'both.': ['Thank'],
#  'proudly': ['joined', 'serve.', 'in'],
#  'NASA': ['Deputy'],
#  'Deputy': ['Administrator', 'Secretary'],
#  'Administrator': ['Jim'],
#  'Jim': ['Morhard,'],
#  'Morhard,': ['Deputy'],
#  'Secretary': ['Of'],
#  'Of': ['Energy'],
#  'Energy': ['Dan'],
#  'Brouillette,': ['Governor'],
#  'Matt': ['Bevin'],
#  'Bevin': ['of'],
#  'Kentucky,': ['your'],
#  'attorney': ['general,'],
#  'general,': ['Ken'],
#  'Paxton,': ['a'],
#  'couple': ['of'],
#  'senators.': ['Kevin,', 'We'],
#  'Kevin,': ['thank', 'very'],
#  'being': ['here.', 'here.', 'here.'],
#  'here.': ['Thank', 'Among', 'I'],
#  'Kevin.': ['Thank'],
#  'Congress': ['people.'],
#  "There's": ['Mr.'],
#  'Brady,': ['Congressman'],
#  'Congressman': ['Brady.'],
#  'Brady.': ['He'],
#  'He': ['gave'],
#  'gave': ['us'],
#  'us': ['a', 'some'],
#  'very,': ['very', 'very'],
#  'nice': ['tax'],
#  'tax': ['cut', 'cuts', 'cuts', 'cuts', 'reforms'],
#  'cut': ['folks.', 'to'],
#  'folks.': ['Thank'],
#  'Among': ['the'],
#  'leaders': ['here'],
#  'remarkable': ['celebration'],
#  'celebration': ['are'],
#  'many': ['members', 'years.'],
#  'House': ['and', 'majority', 'and'],
#  'Senate.': ["They're"],
#  "They're": ['all', 'developing'],
#  'audience,': ['including'],
#  'including': ['House', 'American'],
#  'majority': ['leader,'],
#  'leader,': ['Steny', 'the'],
#  'Steny': ['Hoyer,'],
#  'Hoyer,': ['and'],
#  'again,': ['senators'],
#  'Cornyn,': ['Cruz.'],
#  'In': ['my', 'a', 'the', 'both', 'the', 'the', '2018', 'November,'],
#  'campaign': ['for'],
#  'president,': ['I'],
#  'promised': ['all'],
#  'that.': ['If', 'On', 'We', 'We', 'Because'],
#  'If': ['we'],
#  'were': ['elected,', 'thrilled'],
#  'elected,': ['India'],
#  'would': ['have', 'invest', 'threaten', 'raid', 'like'],
#  'true': ['and'],
#  'friend': ['in', 'as'],
#  'White': ['House'],
#  'can': ['tell', 'tell', 'live'],
#  'tell': ['you,', 'you.'],
#  'never': ['had',
#   'before',
#   'in',
#   'been',
#   'invested',
#   'invested',
#   'before,',
#   'allow'],
#  'had': ['a'],
#  'better': ['friend', 'time'],
#  'president': ['that', 'of'],
#  'President': ['Donald'],
#  'Donald': ['Trump.'],
#  'Trump.': ['That'],
#  'That': ['I', 'means', 'sounds', 'means'],
#  'prime': ['minister', 'working'],
#  'minister': ['knows'],
#  'knows': ['that.', 'that'],
#  'On': ['this', 'Tuesday,'],
#  'day,': ["I'm"],
#  "I'm": ['happy'],
#  'report': ['that'],
#  'relationship': ['between'],
#  'between': ['the', 'our', 'our', 'our'],
#  'United': ['States',
#   'States,',
#   'States,',
#   'States',
#   'States,',
#   'States',
#   'States',
#   'States',
#   'States,',
#   'States',
#   'States',
#   'States',
#   'States',
#   'States.',
#   'States'],
#  'States': ['and',
#   'has',
#   'because',
#   'like',
#   'is',
#   'and',
#   'Space',
#   'and',
#   'also',
#   'and'],
#  'stronger': ['than', 'security'],
#  'than': ['ever', '$3,000', 'ever', 'energy', 'ever'],
#  'ever': ['before.',
#   'recorded',
#   'happened.',
#   'before.',
#   'NBA',
#   'tri-service',
#   'before,'],
#  'before.': ['The', 'And'],
#  'ties': ['between', 'between'],
#  'two': ['nations', 'national', 'years,', 'Japanese'],
#  'nations': ['are', 'with', 'even', 'stronger,'],
#  'grounded': ['in'],
#  'common': ['values'],
#  'values': ['and'],
#  'commitment': ['to', 'to'],
#  'democracy.': ['We'],
#  'free': ['nations', 'benefits', 'thinkers,', 'people.'],
#  'faith': ['and', 'of'],
#  'fierce': ['devotion'],
#  'devotion': ['to'],
#  'national': ['independence.', 'constitutions'],
#  'independence.': ['We'],
#  'governed': ['by'],
#  'rule': ['of'],
#  'law,': ['guided'],
#  'guided': ['by'],
#  'justice,': ['and'],
#  'strengthened': ['by'],
#  'liberty.': ['Our'],
#  'Our': ['two', 'people'],
#  'constitutions': ['both'],
#  'both': ['begin', 'India', 'oil'],
#  'begin': ['with'],
#  'three': ['beautiful'],
#  'beautiful': ['words,', 'phrase,'],
#  'words,': ['"We'],
#  '"We': ['the'],
#  'People."': ['That'],
#  'means': ['that', 'more'],
#  'AMD': ['India'],
#  'alike,': ['we'],
#  'honor,': ['respect,'],
#  'respect,': ['trust,'],
#  'trust,': ['empower'],
#  'empower': ['and'],
#  'fight': ['for'],
#  'citizens': ['we', 'first.', 'before'],
#  'serve.': ['Under'],
#  'Under': ['Prime'],
#  "Modi's": ['leadership,', 'pro-growth'],
#  'leadership,': ['the'],
#  'world': ['is', 'and', 'are', 'class', 'and'],
#  'witnessing': ['a'],
#  'strong': ['sovereign'],
#  'sovereign': ['and'],
#  'thriving': ['Republic'],
#  'Republic': ['of'],
#  'decade,': ['with', '140'],
#  'help': ['of', 'write', 'achieve'],
#  'pro-growth': ['reforms,'],
#  'reforms,': ['India'],
#  'has': ['lifted',
#   'just',
#   'taken',
#   'never',
#   'never',
#   'launched',
#   '27,000',
#   'always',
#   'a'],
#  'lifted': ['nearly'],
#  '300': ['million'],
#  'people': ['out', 'are', 'have', 'will', 'out', 'wealthier,', 'Prime'],
#  'out': ['of', 'of'],
#  'poverty': ['and'],
#  'an': ['incredible', 'even', 'even'],
#  'number.': ['Incredible.', 'Unemployment'],
#  'Incredible.': ["That's"],
#  'incredible.': ['In'],
#  'next': ['decade,'],
#  '140': ['million'],
#  'households': ['will'],
#  'rise': ['to'],
#  'middle': ['class.'],
#  'class.': ['In'],
#  'States,': ["we're", 'thanks', 'there', 'which'],
#  "we're": ['seeing', 'doing', 'creating', 'working'],
#  'seeing': ['something'],
#  'something': ['really'],
#  'really': ['remarkable.'],
#  'remarkable.': ['Our'],
#  'prospering': ['like'],
#  'like': ['never', 'they', 'it', 'never', 'to'],
#  'before': ['because', 'we'],
#  'because': ['we', 'they', "we're"],
#  'slashing': ['bureaucracy'],
#  'bureaucracy': ['and'],
#  'cutting': ['job'],
#  'killing': ['red', 'regulations,'],
#  'red': ['tape.'],
#  'tape.': ['In'],
#  'thanks': ['to'],
#  'massive': ['tax'],
#  'cuts': ['and', 'and', 'and'],
#  'congressmen': ['and'],
#  'women': ['that'],
#  'pro': ['worker'],
#  'worker': ['policies,', 'has'],
#  'policies,': ['our'],
#  'economy': ['is', 'and'],
#  'breaking': ['one'],
#  'record': ['after', 'number', 'numbers.'],
#  'after': ['another.'],
#  'another.': ['Since'],
#  'Since': ['my', 'taking'],
#  'election,': ['we'],
#  'created': ['over', 'over'],
#  '6': ['million'],
#  'new': ['jobs.',
#   'Texas',
#   'hires',
#   'businesses',
#   'jobs',
#   'defense',
#   'cures',
#   'frontiers'],
#  'jobs.': ['We', 'They'],
#  '750,000': ['jobs'],
#  'jobs': ['right', 'to', 'right'],
#  'right': ['here', 'here', 'here', 'here', 'now'],
#  'importantly,': ['that'],
#  'includes': ['70,000'],
#  '70,000': ['new'],
#  'manufacturing': ['jobs.'],
#  'They': ['said', 'have', 'want'],
#  'said': ['that'],
#  "couldn't": ['be'],
#  'done.': ['Unemployment', 'And'],
#  'Unemployment': ['…', 'in', 'among'],
#  '…': ['Think', 'country,', 'Free'],
#  'Think': ['of'],
#  'this.': ['Unemployment'],
#  'currently': ['at'],
#  'lowest': ['rate', 'level', 'levels'],
#  'rate': ['ever', 'among', 'in'],
#  'recorded': ['in'],
#  'country,': ['and', 'no', 'and'],
#  'unemployment': ['in', 'rate'],
#  'reached': ['the', 'their', '$18'],
#  'level': ['in'],
#  '51': ['years'],
#  'years': ['and'],
#  'soon': ['we', 'be'],
#  'think': ['that'],
#  'broken': ['to'],
#  'among': ['African', 'Indian'],
#  'African': ['Americans,'],
#  'Americans,': ['Asian', 'and'],
#  'Asian': ['Americans,'],
#  'Hispanic': ['Americans'],
#  'their': ['lowest', 'taxes,', 'field,', 'children', 'very,'],
#  'levels': ['in'],
#  'Over': ['the', 'the'],
#  'last': ['two', 'year,'],
#  'years,': ['the'],
#  'dropped': ['by'],
#  '33': ['and'],
#  'third': ['percent.'],
#  'percent.': ['Wages'],
#  'Wages': ['are'],
#  'rising,': ['incomes'],
#  'incomes': ['are'],
#  'soaring,': ['and'],
#  'inequality': ['is'],
#  'falling': ['at'],
#  'fastest': ['rate', 'growing'],
#  'many,': ['many'],
#  'years.': ['In', 'And'],
#  'past': ['12', 'decade.'],
#  '12': ['months'],
#  'alone,': ['the'],
#  'average': ['worker', 'American'],
#  'taken': ['home', 'place'],
#  'home': ['$1,000'],
#  '$1,000': ['extra'],
#  'extra': ['in'],
#  'rising': ['wages'],
#  'wages': ['and'],
#  '$3,000': ['with', 'every'],
#  'other': ['things'],
#  'things': ['that'],
#  "we've": ['done.'],
#  'first': ['time', 'ever', 'time', 'ever', 'duty'],
#  'history,': ['most'],
#  'hires': ['of'],
#  'age': ['are'],
#  'minorities': ['and'],
#  'women.': ['First'],
#  'First': ['time'],
#  "that's": ['ever', "what's"],
#  'happened.': ['Through'],
#  'Through': ['our'],
#  'pledge': ['to', 'to'],
#  'workers,': ['we'],
#  'secured': ['commitments'],
#  'commitments': ['for'],
#  '14': ['million'],
#  'employment': ['and', 'in'],
#  'training': ['opportunities'],
#  'opportunities': ['for'],
#  'workers': ['done', 'in', 'who'],
#  'done': ['through'],
#  'through': ['our'],
#  'companies.': ['We'],
#  'passed': ['the'],
#  'biggest': ['tax', 'tax'],
#  'reforms': ['in'],
#  'slashed': ['a'],
#  'number': ['of', 'one', 'one'],
#  'regulations,': ['giving'],
#  'giving': ['the'],
#  'household': ['more'],
#  'more': ['than', 'prosperous', 'important', 'jobs,'],
#  'year': ['and', 'from'],
#  'no': ['matter', 'issue'],
#  'matter': ['how'],
#  'how': ['long'],
#  'long': ['the'],
#  'presidency,': ['have'],
#  'regulations': ['been'],
#  'extent.': ['Everyday,'],
#  'Everyday,': ['the'],
#  'community': ['is', 'with'],
#  'helping': ['to'],
#  'strengthen': ['our'],
#  'country': ['and', 'like', 'and', 'illegally.'],
#  'build': ['our', 'a'],
#  'future.': ['Indian', 'To'],
#  'pioneering': ['groundbreaking'],
#  'groundbreaking': ['medicines'],
#  'medicines': ['to'],
#  'save': ['countless', 'millions'],
#  'countless': ['lives.'],
#  'lives.': ["They're", 'We'],
#  'developing': ['revolutionary'],
#  'revolutionary': ['technology'],
#  'technology': ['that'],
#  'changing': ['the'],
#  "they're": ['founding'],
#  'founding': ['new'],
#  'businesses': ['that'],
#  'provide': ['jobs'],
#  'thousands': ['of', 'of', 'of'],
#  'fellow': ['citizens.'],
#  'citizens.': ['Prime'],
#  'Modi,': ['I', 'my', "who's"],
#  'look': ['forward'],
#  'forward': ['to', 'to'],
#  'make': ['our', 'the', 'our'],
#  'even': ['more', 'stronger', 'close.', 'grander', 'be'],
#  'prosperous': ['than'],
#  "what's": ['happening.', 'taken'],
#  'happening.': ['The'],
#  'economic': ['miracles'],
#  'miracles': ['taking'],
#  'taking': ['place', 'office,', 'unprecedented'],
#  'place': ['today', 'in'],
#  'beginning.': ['Here'],
#  'Here': ['in', 'in'],
#  'hire,': ['invest,'],
#  'invest,': ['grow,'],
#  'grow,': ['and'],
#  'pursue': ['your'],
#  'dreams.': ['Indian'],
#  'companies': ['employ'],
#  'employ': ['tens'],
#  'tens': ['of'],
#  'range': ['of'],
#  'industries,': ['including'],
#  'steel.': ['In'],
#  '2018': ["India's"],
#  "India's": ['JSW', 'growing'],
#  'JSW': ['Steel'],
#  'Steel': ['announced'],
#  'announced': ['that', 'a'],
#  'it': ['would', 'is', 'comes', 'coming', 'on', 'to', "won't"],
#  'invest': ['up'],
#  'up': ['to', 'to'],
#  '$500': ['million'],
#  'revitalize': ['a'],
#  'shuttered': ['steel'],
#  'steel': ['plant'],
#  'plant': ['in'],
#  'Ohio.': ['And'],
#  'welcome': ["India's"],
#  'growing': ['investments', 'markets.'],
#  'investments': ['right'],
#  'Lone': ['Star'],
#  'Star': ['State.'],
#  'State.': ['Nations'],
#  'Nations': ['around'],
#  'around': ['the'],
#  'investing': ['in'],
#  'they': ['know', 'are', 'increase', "won't"],
#  'best': ['economy', 'workers', 'chance'],
#  'world.': ['They', 'We'],
#  'invested': ['in', 'in'],
#  'today.': ['And', 'And'],
#  'everybody': ['and', 'for'],
#  'say': ["it's", 'that'],
#  "it's": ['reciprocal', 'a', 'African-American,'],
#  'reciprocal': ['because'],
#  'thing': ['in'],
#  'Tuesday,': ['two'],
#  'Japanese': ['companies,'],
#  'companies,': ['Toyota'],
#  'Toyota': ['and'],
#  'Aisin,': ['announced'],
#  'combined': ['investment'],
#  'investment': ['of'],
#  'almost': ['$800'],
#  '$800': ['million,'],
#  'million,': ['which'],
#  'which': ['will', 'could'],
#  'create': ['over'],
#  '900': ['new'],
#  'Texas.': ['At', 'That'],
#  'At': ['the'],
#  'expand': ['American', 'employment'],
#  'exports': ['to', 'to', 'to', 'continue', 'not'],
#  "world's": ['fastest'],
#  'markets.': ['We'],
#  'committed': ['to', 'to'],
#  'ensuring': ['the'],
#  'access': ['to', 'to', 'to'],
#  'finest': ['goods'],
#  'goods': ['in'],
#  'product': ['stamped'],
#  'stamped': ['with'],
#  'phrase,': ['"Made'],
#  '"Made': ['in'],
#  'USA."': ['And'],
#  'soon,': ['India'],
#  'class': ['American'],
#  'product,': ['NBA'],
#  'NBA': ['basketball.', 'basketball'],
#  'basketball.': ['Wow,'],
#  'Wow,': ['sounds'],
#  'sounds': ['good.', 'good.'],
#  'good.': ['That', 'Next'],
#  'Next': ['week'],
#  'week': ['thousands'],
#  'gather': ['in'],
#  'Mumbai': ['to'],
#  'watch': ['the'],
#  'basketball': ['game'],
#  'game': ['in'],
#  'Am': ['I'],
#  'invited,': ['Mr.'],
#  'Minister?': ['I'],
#  'may': ['come.', 'come.'],
#  'come.': ['Be', 'When', 'I'],
#  'Be': ['careful.'],
#  'careful.': ['I'],
#  'When': ['it'],
#  'comes': ['to'],
#  'expanding': ['our'],
#  'commercial': ['relationship,'],
#  'relationship,': ['no', 'holding'],
#  'issue': ['is'],
#  'energy': ['security.'],
#  'security.': ['For', 'Border'],
#  'For': ['the'],
#  'ever,': ['the'],
#  'producer': ['of'],
#  'oil': ['and'],
#  'natural': ['gas', 'gas'],
#  'gas': ['on', 'exports'],
#  'planet': ['earth'],
#  'earth': ['and'],
#  'far,': ['with'],
#  'much': ['of'],
#  'coming': ['right', 'years.'],
#  'from': ['the', 'the', 'the'],
#  'jobs,': ['higher'],
#  'higher': ['wages,'],
#  'wages,': ['and'],
#  'lower': ['prices'],
#  'prices': ['at'],
#  'pump.': ['Yesterday,'],
#  'Yesterday,': ['we'],
#  'hear': ['about'],
#  'about': ['the'],
#  'company': ['Petronas'],
#  'Petronas': ['pledge'],
#  'purchase': ['up'],
#  '5': ['million'],
#  'tons': ['of'],
#  'LNG': ['per', 'exports'],
#  'per': ['year'],
#  'could': ['lead'],
#  'lead': ['to'],
#  'billions': ['of'],
#  'dollars': ['of'],
#  'plenty': ['of'],
#  'it.': ['Over'],
#  'year,': ['crude'],
#  'crude': ['exports'],
#  'grown': ['by'],
#  '400%': ['and'],
#  'liquefied': ['natural'],
#  'continue': ['to', 'to'],
#  'soar': ['at'],
#  'numbers.': ['Thank'],
#  'These': ['tremendous'],
#  'only': ['expand'],
#  'America,': ['but', "we're"],
#  'but': ['they'],
#  'increase': ['freedom'],
#  'freedom': ['and'],
#  'security': ['for', 'partnership.', 'are', 'is', 'is'],
#  'To': ['keep', 'help'],
#  'keep': ['our', 'our'],
#  'safe,': ['the', 'we'],
#  'forging': ['an'],
#  'partnership.': ['US'],
#  'defense': ['sales', 'mechanisms', 'deals', 'relationship,', 'of'],
#  'sales': ['to'],
#  '$18': ['billion'],
#  'billion': ['over'],
#  'decade.': ['We'],
#  'greatest': ['defense'],
#  'mechanisms': ['and'],
#  'equipment': ['anywhere'],
#  'anywhere': ['in'],
#  'well.': ["We're"],
#  'looking': ['forward'],
#  'concluding': ['several'],
#  'several': ['new'],
#  'deals': ['very'],
#  'soon.': ['There'],
#  'There': ['are'],
#  'them': ['in'],
#  'works.': ['Here'],
#  'creating': ['the'],
#  'Space': ['Force'],
#  'Force': ['and'],
#  'closely': ['with'],
#  'enhance': ['space'],
#  'space': ['cooperation.'],
#  'cooperation.': ['In'],
#  'November,': ['the'],
#  'demonstrate': ['a'],
#  'dramatic': ['progress'],
#  'progress': ['of'],
#  'holding': ['the'],
#  'tri-service': ['military'],
#  'military': ['exercise', 'service'],
#  'exercise': ['between'],
#  'nations.': ["It's", 'We'],
#  'Tiger': ['Triumph.'],
#  'Triumph.': ['Good'],
#  'Good': ['name,'],
#  'name,': ["it's"],
#  'good': ['name.', 'name.'],
#  'name.': ['Very', 'Today,'],
#  'Very': ['good'],
#  'Today,': ['we'],
#  'honor': ['all', 'the', 'to'],
#  'brave': ['American'],
#  'service': ['members'],
#  'who': ['work', 'would', 'right', 'work', 'would', 'enter', 'have'],
#  'work': ['together', 'hard,', 'in'],
#  'together': ['to'],
#  'safeguard': ['our'],
#  'freedom.': ['We'],
#  'stand': ['proudly'],
#  'liberty': ['and'],
#  'protecting': ['innocent'],
#  'innocent': ['civilians'],
#  'civilians': ['from'],
#  'threat': ['of'],
#  'radical': ['Islamic'],
#  'Islamic': ['terrorism.'],
#  'terrorism.': ['Thank'],
#  'Both': ['India'],
#  'must': ['protect', 'always'],
#  'protect': ['our'],
#  'borders.': ['Since'],
#  'office,': ['my'],
#  'launched': ['a'],
#  'far-reaching': ['effort'],
#  'effort': ['to'],
#  'improve': ['screening'],
#  'screening': ['and'],
#  'vetting': ['of', 'efforts', 'efforts'],
#  'applications': ['for'],
#  'entry.': ['We'],
#  'ensure': ['that'],
#  'those': ['who', 'in', 'who'],
#  'threaten': ['our'],
#  'denied': ['admission'],
#  'admission': ['into'],
#  'into': ['our', 'our'],
#  'enhancing': ['our', 'our'],
#  'efforts': ['like-', 'like'],
#  'like-': ['…'],
#  'before,': ['not', 'and'],
#  'close.': ["We're", 'I'],
#  'daily': ['basis,'],
#  'basis,': ['and'],
#  "we'll": ['soon'],
#  'setting': ['records'],
#  'records': ['in'],
#  'aspects': ['of'],
#  'border': ['security.', 'and'],
#  'Border': ['security', 'security'],
#  'vital': ['to', 'to'],
#  'States.': ['Border'],
#  'further': ['taking'],
#  'unprecedented': ['action'],
#  'action': ['to'],
#  'finally': ['secure'],
#  'secure': ['our'],
#  'southern': ['border', 'border.'],
#  'stop': ['illegal'],
#  'illegal': ['immigration.', 'immigrants.', 'immigrants'],
#  'immigration.': ['I'],
#  'Mexico,': ['who'],
#  'now': ['has'],
#  '27,000': ['soldiers'],
#  'soldiers': ['on'],
#  'border.': ["It's"],
#  'short': ['period'],
#  'period': ['of'],
#  'time.': ['Illegal'],
#  'Illegal': ['immigration'],
#  'immigration': ['is'],
#  'deeply': ['unfair'],
#  'unfair': ['to'],
#  'millions': ['of', 'of', 'and', 'of'],
#  'wonderful': ['legal'],
#  'legal': ['immigrants'],
#  'immigrants': ['who', 'that'],
#  'hard,': ['pay'],
#  'pay': ['their'],
#  'taxes,': ['follow'],
#  'follow': ['our'],
#  'rules,': ['and'],
#  'obey': ['our'],
#  'laws.': ['Yet'],
#  'Yet': ['there'],
#  'Washington': ['who'],
#  'raid': ['your'],
#  'healthcare': ['to', 'or'],
#  'Free': ['benefits.'],
#  'benefits.': ['They'],
#  'fund': ['free'],
#  'benefits': ['to'],
#  'enter': ['our'],
#  'illegally.': ['We'],
#  "don't": ['want', 'want', 'do'],
#  'do': ['that.', 'that.', 'it,'],
#  'Because': ['if'],
#  'if': ['we'],
#  'it,': ['they'],
#  "won't": ['come.', 'even'],
#  'allow': ['politicians'],
#  'politicians': ['to'],
#  'away': ['your'],
#  'or': ['give'],
#  'give': ['it', 'their', 'us'],
#  'immigrants.': ['My'],
#  'believes': ['our'],
#  'duty': ['is'],
#  'highest': ['loyalty'],
#  'loyalty': ['of'],
#  'all.': ['We', 'God'],
#  'always': ['be', 'been', 'give'],
#  'people,': ['whether', 'for'],
#  'whether': ["it's"],
#  'African-American,': ['Hispanic-American,'],
#  'Hispanic-American,': ['Indian-American.'],
#  'Indian-American.': ['We'],
#  'going': ['to', 'to', 'to'],
#  'care': ['of', 'of', 'of'],
#  'first.': ['We'],
#  'Indian-American': ['citizens'],
#  'pour': ['into'],
#  'family,': ['immigrant'],
#  'immigrant': ['and'],
#  'US-born,': ['can'],
#  'live': ['in'],
#  'safe': ['community'],
#  'school,': ['work'],
#  'love,': ['and'],
#  'chance': ['to'],
#  'reach': ['the'],
#  'dream.': ['We', 'Just'],
#  'concluding,': ['I'],
#  'pioneers': ['and'],
#  'patriots,': ['risk-takers'],
#  'risk-takers': ['and'],
#  'thinkers,': ['and'],
#  'dedicated': ['workers'],
#  'honed': ['a'],
#  'trade,': ['mastered'],
#  'mastered': ['their'],
#  'field,': ['and'],
#  'teach': ['their'],
#  'children': ['to'],
#  'best.': ['Every'],
#  'Every': ['day'],
#  'day': ['Indian-Americans'],
#  'Indian-Americans': ['help'],
#  'write': ['the'],
#  'story': ['of'],
#  'greatness,': ['and'],
#  'crucial': ['part'],
#  'part': ['to'],
#  'play': ['in'],
#  'building': ['an'],
#  'grander': ['and'],
#  'greater': ['American'],
#  'achieve': ['that', 'incredible'],
#  'exciting': ['vision,'],
#  'vision,': ['we'],
#  'strengthening': ['our'],
#  'cherished': ['bonds'],
#  'bonds': ['with'],
#  'proving': ['the'],
#  'awesome': ['power'],
#  'power': ['of'],
#  'democracy': ['and'],
#  'unlimited': ['potential'],
#  'potential': ['of'],
#  'Together,': ['we'],
#  'deepen': ['the'],
#  'dignity': ['of'],
#  'citizens,': ['and'],
#  'advancements': ['for'],
#  'children,': ['and'],
#  'discover': ['new'],
#  'cures': ['and'],
#  'advance': ['cutting-edge'],
#  'cutting-edge': ['technologies'],
#  'technologies': ['and'],
#  'lift': ['millions'],
#  'poverty.': ['We'],
#  'pioneer': ['new'],
#  'frontiers': ['in'],
#  'space,': ['working'],
#  'together,': ['raising'],
#  'raising': ['the'],
#  'sights': ['of'],
#  'humanity.': ['We'],
#  'defend': ['our'],
#  'liberty,': ['and'],
#  'control': ['our'],
#  'destiny.': ['The'],
#  'stronger,': ['our'],
#  'wealthier,': ['our'],
#  'dreamers': ['bigger,'],
#  'bigger,': ['and'],
#  'future': ['brighter'],
#  'brighter': ['than'],
#  'man': ['and'],
#  'leader': ['of'],
#  'friend.': ['Thank'],
#  'God': ['bless', 'bless', 'bless'],
#  'bless': ['you', 'India,', 'America.'],
#  'America.': ['Thank'],
#  'Now': ['I'],
#  'invite': ['onto'],
#  'onto': ['this'],
#  'stage': ['in'],
#  'front': ['of'],
#  'group': ['of'],
#  'unbelievable': ['people'],
#  "who's": ['going'],
#  'some': ['of'],
#  'wisdom.': ['His'],
#  'His': ['wisdom'],
#  'wisdom': ['is'],
#  'indeed': ['great.'],
#  'great.': ['Thank']}

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(test_dict)
# Out:
# "On a moment to millions of America's greatest, most loyal friends, Prime Minister Modi, who's."
